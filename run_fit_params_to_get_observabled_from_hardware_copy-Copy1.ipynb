# %%
import pennylane as qml
import pennylane.numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import json

# %%
import vqd

# %%
d_observables = qml.data.Dataset()
d_observables.read('observable_results_v2.dat')

# %%
# only the n_qubits value actually matters here since we're not doing optimization
# but the VQD class takes them all during instantiation
total_time = 2.0
#total_time = 0.5
dt = 0.05
max_iterations = 500
cost_threshold = 0.0001
n_qubits = 3 # this needs to be 3, however!
interface = 'autograd'

# %%
#device_type = "qiskit.ibmq" # change this to run on real device
device_type = 'braket.aws.qubit'
s3 = ("amazon-braket-3fd3189a48a9", "ionq_runs")

# %%
backend="ionq"

# dev = qml.device(device_type, wires=n_qubits, backend=backend, 
#                               hub='qhack-event', group='main', project='level-1',
#                  ibmqx_token='') #insert token string!!

# dev = qml.device(device_type, wires=n_qubits, backend=backend, 
#                  ibmqx_token='') #insert token string!!

dev = qml.device(device_type, wires=n_qubits, 
                 device_arn="arn:aws:braket:::device/qpu/ionq/ionQdevice", 
                 s3_destination_folder=s3)

# %%
shots = 80 # Change this value

# extract optimized circuit parameters from simulations
results = d_observables.observable_results[shots]

# create data storage structures
observable_results = {}
observables = []
variances = []
time_vals = []
observable_results[shots] = {}

# use the VQD class
vqdrunner = vqd.VQD(interface, 
                        total_time, 
                        dt, 
                        max_iterations, 
                        cost_threshold, 
                        n_qubits, 
                        shots=shots, 
                        optimization_step_size=0.05,
                        predefined_observable_device = dev)

# loop through time steps to run circuit with parameters
for a_time, params in zip(results['time'], results['final_params_v_time']):
    print(f"time :{a_time}")
    print("circuit params")
    print(params)
    
    time_vals.append(a_time)
    print('running circuits')
    observables.append(vqdrunner.qnode_three_spins_observables(params, shots=shots))
    variances.append(vqdrunner.qnode_three_spins_observables_variance(params, shots=shots))
    print('')
    
observable_results[shots]['observables'] = observables
observable_results[shots]['variances'] = variances
observable_results[shots]['time'] = time_vals
    
d_observables_on_device = qml.data.Dataset(on_device_observable_results = observable_results)
d_observables_on_device.write(f'{device_type}_{backend}_shots{shots}_observable_results_v2.dat')
# Out:
# time :0.30000000000000004
# circuit params
# [0.33347512 0.32932446 0.33347512 0.0136604  0.0136604  0.02259439
#  0.04492575 0.02259439 0.00479662 0.00479662 0.33329913 0.32874192
#  0.33329913 0.0214051  0.0214051  0.02404055 0.04769939 0.02404055]
# running circuits
#
# time :0.35000000000000003
# circuit params
# [0.38145244 0.37584226 0.38145244 0.01840615 0.01840615 0.02690479
#  0.05345623 0.02690479 0.00636217 0.00636217 0.38115458 0.37487533
#  0.38115458 0.02946938 0.02946938 0.02914889 0.05770472 0.02914889]
# running circuits
#
# time :0.4
# circuit params
# [0.42935531 0.42207592 0.42935531 0.02377498 0.02377498 0.0313545
#  0.0622694  0.0313545  0.00815283 0.00815283 0.42889678 0.42059783
#  0.42889678 0.03857913 0.03857913 0.03451804 0.06816368 0.03451804]
# running circuits
#
# time :0.45
# circuit params
# [0.47717754 0.46802829 0.47717754 0.02983548 0.02983548 0.03609633
#  0.07168204 0.03609633 0.01029358 0.01029358 0.47652482 0.4659075
#  0.47652482 0.0485353  0.0485353  0.04016616 0.07910749 0.04016616]
# running circuits
#
# time :0.5
# circuit params
# [0.52506024 0.51385642 0.52506024 0.03673267 0.03673267 0.04130497
#  0.08206158 0.04130497 0.01298304 0.01298304 0.52419103 0.5109598
#  0.52419103 0.05914334 0.05914334 0.04605872 0.09047034 0.04605872]
# running circuits
#
# time :0.55
# circuit params
# [0.57340215 0.55999356 0.57340215 0.0446679  0.0446679  0.04714402
#  0.09377964 0.04714402 0.01653151 0.01653151 0.57231516 0.55619595
#  0.57231516 0.0701938  0.0701938  0.05201775 0.10191745 0.05201775]
# running circuits
#
# time :0.6000000000000001
# circuit params
# [0.62257451 0.60717679 0.62257451 0.05380606 0.05380606 0.05364711
#  0.1071066  0.05364711 0.02277093 0.02277093 0.62138234 0.60259846
#  0.62138234 0.08099165 0.08099165 0.05605508 0.10964911 0.05605508]
# running circuits
#
# time :0.65
# circuit params
# [0.67179505 0.65486193 0.67179505 0.06426852 0.06426852 0.06103038
#  0.12225936 0.06103038 0.03186124 0.03186124 0.67073911 0.64984396
#  0.67073911 0.08983704 0.08983704 0.05800446 0.11336754 0.05800446]
# running circuits
#
# time :0.7000000000000001
# circuit params
# [0.7210811  0.70306635 0.7210811  0.07578364 0.07578364 0.06888276
#  0.13835536 0.06888276 0.04230413 0.04230413 0.72033931 0.69776151
#  0.72033931 0.09722801 0.09722801 0.05891031 0.11510266 0.05891031]
# running circuits
#
# time :0.75
# circuit params
# [0.77045336 0.75182533 0.77045336 0.08811911 0.08811911 0.07700209
#  0.15492099 0.07700209 0.05322491 0.05322491 0.77016371 0.74625043
#  0.77016371 0.10360061 0.10360061 0.05931148 0.11589119 0.05931148]
# running circuits
#
# time :0.8
# circuit params
# [0.81992652 0.80116487 0.81992652 0.10110191 0.10110191 0.08533013
#  0.1717378  0.08533013 0.06408854 0.06408854 0.82020304 0.79523739
#  0.82020304 0.10924902 0.10924902 0.05947617 0.11626446 0.05947617]
# running circuits
#
# time :0.8500000000000001
# circuit params
# [0.86950334 0.85109663 0.86950334 0.11458365 0.11458365 0.09384969
#  0.18867428 0.09384969 0.07457213 0.07457213 0.87044379 0.84466827
#  0.87044379 0.11435654 0.11435654 0.05946672 0.11639623 0.05946672]
# running circuits
#
# time :0.9
# circuit params
# [0.91914432 0.90157384 0.91914432 0.12839429 0.12839429 0.10251446
#  0.20558843 0.10251446 0.08447259 0.08447259 0.92083242 0.89446161
#  0.92083242 0.11901488 0.11901488 0.05920642 0.11622059 0.05920642]
# running circuits
#
# time :0.9500000000000001
# circuit params
# [0.96872525 0.95242477 0.96872525 0.14229068 0.14229068 0.11121266
#  0.22226867 0.11121266 0.09365244 0.09365244 0.97123459 0.94445388
#  0.97123459 0.12321709 0.12321709 0.0585314  0.1154983  0.0585314 ]
# running circuits
#
# time :1.0
# circuit params
# [1.01818537 1.00352681 1.01818537 0.15588891 0.15588891 0.11974772
#  0.23836074 0.11974772 0.10206203 0.10206203 1.02159325 0.99461272
#  1.02159325 0.1269063  0.1269063  0.0571481  0.11373182 0.0571481 ]
# running circuits
#
# time :1.05
# circuit params
# [1.06765575 1.05495225 1.06765575 0.16879866 0.16879866 0.12793569
#  0.25353888 0.12793569 0.10965975 0.10965975 1.07204213 1.04509643
#  1.07204213 0.13013167 0.13013167 0.05481978 0.11053987 0.05481978]
# running circuits
#
# time :1.1
# circuit params
# [1.11722903 1.1067081  1.11722903 0.18071804 0.18071804 0.13562981
#  0.2675779  0.13562981 0.11638868 0.11638868 1.12267029 1.09595053
#  1.12267029 0.13299145 0.13299145 0.05145705 0.1057924  0.05145705]
# running circuits
#
# time :1.1500000000000001
# circuit params
# [1.16696931 1.1587728  1.16696931 0.19139669 0.19139669 0.14268571
#  0.28027267 0.14268571 0.12224202 0.12224202 1.17354197 1.14718152
#  1.17354197 0.13559279 0.13559279 0.04701834 0.09941398 0.04701834]
# running circuits
#
# time :1.2000000000000002
# circuit params
# [1.21692732 1.21112526 1.21692732 0.20062261 0.20062261 0.14895137
#  0.291406   0.14895137 0.12727529 0.12727529 1.22471294 1.19879158
#  1.22471294 0.13805648 0.13805648 0.04148636 0.09134171 0.04148636]
# running circuits
#
# time :1.25
# circuit params
# [1.26700664 1.26355963 1.26700664 0.2082408  0.2082408  0.15428179
#  0.30078082 0.15428179 0.13158208 0.13158208 1.27611492 1.25064529
#  1.27611492 0.14038851 0.14038851 0.03490065 0.08154321 0.03490065]
# running circuits
#
# time :1.3
# circuit params
# [1.31708717 1.31583971 1.31708717 0.21413008 0.21413008 0.15854083
#  0.30819674 0.15854083 0.13530599 0.13530599 1.32768981 1.30264536
#  1.32768981 0.14256747 0.14256747 0.0273009  0.06995312 0.0273009 ]
# running circuits
#
# time :1.35
# circuit params
# [1.36702078 1.36768986 1.36702078 0.21820561 0.21820561 0.16160751
#  0.31345776 0.16160751 0.13862377 0.13862377 1.37940004 1.35474353
#  1.37940004 0.14458558 0.14458558 0.01871373 0.05645836 0.01871373]
# running circuits
#
# time :1.4000000000000001
# circuit params
# [1.41658322 1.41872187 1.41658322 0.2204396  0.2204396  0.1633936
#  0.31640715 0.1633936  0.1417138  0.1417138  1.43120596 1.40691262
#  1.43120596 0.14646212 0.14646212 0.00914336 0.04086905 0.00914336]
# running circuits
#
# time :1.4500000000000002
# circuit params
# [ 1.46553711e+00  1.46853097e+00  1.46553711e+00  2.20864276e-01
#   2.20864276e-01  1.63835054e-01  3.16909598e-01  1.63835054e-01
#   1.44743153e-01  1.44743153e-01  1.48310521e+00  1.45917251e+00
#   1.48310521e+00  1.48400986e-01  1.48400986e-01 -1.43418049e-03
#   2.29449306e-02 -1.43418049e-03]
# running circuits
#
# time :1.5
# circuit params
# [ 1.5136654   1.51675298  1.5136654   0.21957564  0.21957564  0.1628855
#   0.31484776  0.1628855   0.14784526  0.14784526  1.53510869  1.51153084
#   1.53510869  0.15086261  0.15086261 -0.01303276  0.00249872 -0.01303276]
# running circuits
#
# time :1.55
# circuit params
# [ 1.56097048  1.56335049  1.56097048  0.21662604  0.21662604  0.16043363
#   0.30997792  0.16043363  0.15116847  0.15116847  1.58729176  1.56399237
#   1.58729176  0.15466137  0.15466137 -0.02557046 -0.02033051 -0.02557046]
# running circuits
#
# time :1.6
# circuit params
# [ 1.6076103   1.60851985  1.6076103   0.2119631   0.2119631   0.15629056
#   0.30192389  0.15629056  0.15487884  0.15487884  1.63971572  1.61646662
#   1.63971572  0.16074577  0.16074577 -0.03880771 -0.04497356 -0.03880771]
# running circuits
#
# time :1.6500000000000001
# circuit params
# [ 1.65378403  1.65256165  1.65378403  0.20536218  0.20536218  0.1501796
#   0.29016691  0.1501796   0.15915117  0.15915117  1.69236615  1.66871446
#   1.69236615  0.17003095  0.17003095 -0.05230478 -0.0703904  -0.05230478]
# running circuits
#
# time :1.7000000000000002
# circuit params
# [ 1.69964715  1.69582489  1.69964715  0.1963139   0.1963139   0.14169049
#   0.27396114  0.14169049  0.16414533  0.16414533  1.74515421  1.72037373
#   1.74515421  0.18335706  0.18335706 -0.06535321 -0.09497627 -0.06535321]
# running circuits
#
# time :1.75
# circuit params
# [ 1.74523342  1.73865415  1.74523342  0.18423815  0.18423815  0.13046854
#   0.25270284  0.13046854  0.1697314   0.1697314   1.79799195  1.77113424
#   1.79799195  0.2012106   0.2012106  -0.07701047 -0.11674604 -0.07701047]
# running circuits
#
# time :1.8
# circuit params
# [ 1.79057129  1.78155138  1.79057129  0.16872851  0.16872851  0.1163447
#   0.2261943   0.1163447   0.17533252  0.17533252  1.85094127  1.82105352
#   1.85094127  0.22365443  0.22365443 -0.08614833 -0.13343651 -0.08614833]
# running circuits
#
# time :1.85
# circuit params
# [ 1.83571262  1.82510312  1.83571262  0.14986619  0.14986619  0.09957425
#   0.19508046  0.09957425  0.17974941  0.17974941  1.90416939  1.87068054
#   1.90416939  0.25035535  0.25035535 -0.09161673 -0.14291786 -0.09161673]
# running circuits
#
# time :1.9000000000000001
# circuit params
# [ 1.88077325  1.86972869  1.88077325  0.12847963  0.12847963  0.08120328
#   0.16138288  0.08120328  0.18115061  0.18115061  1.95772748  1.92081359
#   1.95772748  0.28052225  0.28052225 -0.09272298 -0.14434655 -0.09272298]
# running circuits
#
# time :1.9500000000000002
# circuit params
# [ 1.92586544  1.91542609  1.92586544  0.1056891   0.1056891   0.06281621
#   0.12773118  0.06281621  0.17779156  0.17779156  2.01139484  1.97181845
#   2.01139484  0.31310307  0.31310307 -0.0896589  -0.13903366 -0.0896589 ]
# running circuits
#
# time :2.0
# circuit params
# [ 1.97093883  1.96178739  1.97093883  0.08211682  0.08211682  0.04567043
#   0.09562505  0.04567043  0.16881182  0.16881182  2.06480795  2.02324171
#   2.06480795  0.34735693  0.34735693 -0.08325576 -0.12953512 -0.08325576]
# running circuits

# %%
def get_total_mag(results, shots):
    sig_x = np.tensor(results['observables'])[:,:3]
    sig_z = np.tensor(results['observables'])[:,3:]
    std_sig_x = np.sqrt(np.tensor(results['variances'])[:,:3]/shots)
    std_sig_z = np.sqrt(np.tensor(results['variances'])[:,3:]/shots)

    sum_sig_x = np.sum(sig_x, axis=1)
    sum_sig_z = np.sum(sig_z, axis=1)
    sum_sig_x_std = np.sqrt(np.sum(std_sig_x**2, axis=1))
    sum_sig_z_std = np.sqrt(np.sum(std_sig_z**2, axis=1))
    
    return sum_sig_x, sum_sig_z, sum_sig_x_std, sum_sig_z_std

# %%
fig, ax = plt.subplots(figsize=(8,4))
for s, results in observable_results.items():
    sum_sig_x, sum_sig_z, sum_sig_x_std, sum_sig_z_std = get_total_mag(results, s)
    ax.errorbar(results['time'],sum_sig_x/3, sum_sig_x_std/3, fmt = '.', label=f'{s} shots')
    ax.set_ylabel('$\Sigma_i <\sigma_{x,i}>/3$')
    
exact = json.load(open('exact_solutions.dat'))
ax.plot(exact['times'][:40],exact['Sx'][:40],label ="Exact",linestyle='dashed',linewidth=1.2,color='black')
ax.set_title(f'Results from running on {device_type}:{backend}')
ax.legend()

# %%
fig, ax = plt.subplots(figsize=(8,4))
for s, results in observable_results.items():
    sum_sig_x, sum_sig_z, sum_sig_x_std, sum_sig_z_std = get_total_mag(results, s)
    ax.errorbar(results['time'],sum_sig_z/3, sum_sig_z_std/3, fmt = '.', label=f'{s} shots')
    ax.set_ylabel('$\Sigma_i <\sigma_{z,i}>/3$')

exact = json.load(open('exact_solutions.dat'))
ax.plot(exact['times'][:40],exact['Sz'][:40],label ="Exact",linestyle='dashed',linewidth=1.2,color='black')
ax.legend()

# %%
shots = 2000 # Change this value
skip = 3

# extract optimized circuit parameters from simulations
results = d_observables.observable_results[8000]    #this is a hack

# create data storage structures
observable_results = {}
observables = []
variances = []
time_vals = []
observable_results[shots] = {}

# use the VQD class
vqdrunner = vqd.VQD(interface, 
                        total_time, 
                        dt, 
                        max_iterations, 
                        cost_threshold, 
                        n_qubits, 
                        shots=shots, 
                        optimization_step_size=0.05,
                        predefined_observable_device = dev)

# loop through time steps to run circuit with parameters
for a_time, params in zip(results['time'][::skip], results['final_params_v_time'][::skip]):
    print(f"time :{a_time}")
    print("circuit params")
    print(params)
    
    time_vals.append(a_time)
    print('running circuits')
    observables.append(vqdrunner.qnode_three_spins_observables(params, shots=shots))
    variances.append(vqdrunner.qnode_three_spins_observables_variance(params, shots=shots))
    print('')
    
observable_results[shots]['observables'] = observables
observable_results[shots]['variances'] = variances
observable_results[shots]['time'] = time_vals
    
d_observables_on_device = qml.data.Dataset(on_device_observable_results = observable_results)
d_observables_on_device.write(f'{device_type}_{backend}_shots{shots}_observable_results_v2.dat')
# Out:
# time :0.0
# circuit params
# [ 4.74236727e-02  4.73795575e-02  4.74236727e-02  8.12588205e-05
#   8.12588205e-05  1.17739999e-03  2.35406511e-03  1.17739999e-03
#  -2.99163400e-07 -2.99163400e-07  4.74236527e-02  4.73794787e-02
#   4.74236527e-02  8.18083323e-05  8.18083323e-05  1.17819487e-03
#   2.35565440e-03  1.17819487e-03]
# running circuits
#
# time :0.15000000000000002
# circuit params
# [0.18988607 0.18878113 0.18988607 0.00348369 0.00348369 0.01010032
#  0.02014606 0.01010032 0.00123381 0.00123381 0.18987072 0.18872519
#  0.18987072 0.00500749 0.00500749 0.0102818  0.02050392 0.0102818 ]
# running circuits
#
# time :0.30000000000000004
# circuit params
# [0.33347512 0.32932446 0.33347512 0.0136604  0.0136604  0.02259439
#  0.04492575 0.02259439 0.00479662 0.00479662 0.33329913 0.32874192
#  0.33329913 0.0214051  0.0214051  0.02404055 0.04769939 0.02404055]
# running circuits
#
# time :0.45
# circuit params
# [0.47717754 0.46802829 0.47717754 0.02983548 0.02983548 0.03609633
#  0.07168204 0.03609633 0.01029358 0.01029358 0.47652482 0.4659075
#  0.47652482 0.0485353  0.0485353  0.04016616 0.07910749 0.04016616]
# running circuits
#
# time :0.6000000000000001
# circuit params
# [0.62257451 0.60717679 0.62257451 0.05380606 0.05380606 0.05364711
#  0.1071066  0.05364711 0.02277093 0.02277093 0.62138234 0.60259846
#  0.62138234 0.08099165 0.08099165 0.05605508 0.10964911 0.05605508]
# running circuits
#
# time :0.75
# circuit params
# [0.77045336 0.75182533 0.77045336 0.08811911 0.08811911 0.07700209
#  0.15492099 0.07700209 0.05322491 0.05322491 0.77016371 0.74625043
#  0.77016371 0.10360061 0.10360061 0.05931148 0.11589119 0.05931148]
# running circuits
#
# time :0.9
# circuit params
# [0.91914432 0.90157384 0.91914432 0.12839429 0.12839429 0.10251446
#  0.20558843 0.10251446 0.08447259 0.08447259 0.92083242 0.89446161
#  0.92083242 0.11901488 0.11901488 0.05920642 0.11622059 0.05920642]
# running circuits
#
# time :1.05
# circuit params
# [1.06765575 1.05495225 1.06765575 0.16879866 0.16879866 0.12793569
#  0.25353888 0.12793569 0.10965975 0.10965975 1.07204213 1.04509643
#  1.07204213 0.13013167 0.13013167 0.05481978 0.11053987 0.05481978]
# running circuits
#
# time :1.2000000000000002
# circuit params
# [1.21692732 1.21112526 1.21692732 0.20062261 0.20062261 0.14895137
#  0.291406   0.14895137 0.12727529 0.12727529 1.22471294 1.19879158
#  1.22471294 0.13805648 0.13805648 0.04148636 0.09134171 0.04148636]
# running circuits
#
# time :1.35
# circuit params
# [1.36702078 1.36768986 1.36702078 0.21820561 0.21820561 0.16160751
#  0.31345776 0.16160751 0.13862377 0.13862377 1.37940004 1.35474353
#  1.37940004 0.14458558 0.14458558 0.01871373 0.05645836 0.01871373]
# running circuits
#
# time :1.5
# circuit params
# [ 1.5136654   1.51675298  1.5136654   0.21957564  0.21957564  0.1628855
#   0.31484776  0.1628855   0.14784526  0.14784526  1.53510869  1.51153084
#   1.53510869  0.15086261  0.15086261 -0.01303276  0.00249872 -0.01303276]
# running circuits
#
# time :1.6500000000000001
# circuit params
# [ 1.65378403  1.65256165  1.65378403  0.20536218  0.20536218  0.1501796
#   0.29016691  0.1501796   0.15915117  0.15915117  1.69236615  1.66871446
#   1.69236615  0.17003095  0.17003095 -0.05230478 -0.0703904  -0.05230478]
# running circuits
#
# time :1.8
# circuit params
# [ 1.79057129  1.78155138  1.79057129  0.16872851  0.16872851  0.1163447
#   0.2261943   0.1163447   0.17533252  0.17533252  1.85094127  1.82105352
#   1.85094127  0.22365443  0.22365443 -0.08614833 -0.13343651 -0.08614833]
# running circuits
#
# time :1.9500000000000002
# circuit params
# [ 1.92586544  1.91542609  1.92586544  0.1056891   0.1056891   0.06281621
#   0.12773118  0.06281621  0.17779156  0.17779156  2.01139484  1.97181845
#   2.01139484  0.31310307  0.31310307 -0.0896589  -0.13903366 -0.0896589 ]
# running circuits

# %%
fig, ax = plt.subplots(figsize=(8,4))
for s, results in observable_results.items():
    sum_sig_x, sum_sig_z, sum_sig_x_std, sum_sig_z_std = get_total_mag(results, s)
    ax.errorbar(results['time'],sum_sig_x/3, sum_sig_x_std/3, fmt = '.', label=f'{s} shots')
    ax.set_ylabel('$\Sigma_i <\sigma_{x,i}>/3$')
    
exact = json.load(open('exact_solutions.dat'))
ax.plot(exact['times'][:40],exact['Sx'][:40],label ="Exact",linestyle='dashed',linewidth=1.2,color='black')
ax.set_title(f'Results from running on {device_type}:{backend}')
ax.legend()

# %%
fig, ax = plt.subplots(figsize=(8,4))
for s, results in observable_results.items():
    sum_sig_x, sum_sig_z, sum_sig_x_std, sum_sig_z_std = get_total_mag(results, s)
    ax.errorbar(results['time'],sum_sig_z/3, sum_sig_z_std/3, fmt = '.', label=f'{s} shots')
    ax.set_ylabel('$\Sigma_i <\sigma_{z,i}>/3$')

exact = json.load(open('exact_solutions.dat'))
ax.plot(exact['times'][:40],exact['Sz'][:40],label ="Exact",linestyle='dashed',linewidth=1.2,color='black')
ax.legend()

# %%
# We stop at 800 because 8000 shots run would cost $6424!!!
